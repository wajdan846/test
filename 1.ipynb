# %%
import pickle
import matplotlib.pyplot as plt

rec_fs = 512
rec_subj_name = "sub01"

test_pickle = pickle.load(open(str(rec_subj_name) + ".p", "rb"))

experiment = "ex_paced"

for ex in ["10bpm", "12bpm", "15bpm", "18bpm", "20bpm"]: plt.plot(test_pickle[experiment][ex]["earlobe-wrist"]["earlobe"]["t"],
test_pickle[experiment][ex]["earlobe-wrist"]["earlobe"]["ppg_g"])

pks = test_pickle[experiment][ex]["earlobe-wrist"]["earlobe"]["pks_g"]
if len(pks) != 0:
    plt.plot(pks[1], pks[2], color='red', linestyle='None', marker='o', markersize=1.5, alpha=1.0)

# %%
for ex in ["10bpm", "12bpm", "15bpm", "18bpm", "20bpm"]:plt.plot(test_pickle[experiment][ex]["earlobe-wrist"]["wrist"]["t"],
test_pickle[experiment][ex]["earlobe-wrist"]["wrist"]["ppg_g"])

pks = test_pickle[experiment][ex]["earlobe-wrist"]["wrist"]["pks_g"]
if len(pks) != 0:
    plt.plot(pks[1], pks[2], color='red', linestyle='None', marker='o', markersize=1.5, alpha=1.0)

# %%
for ex in ["10bpm", "12bpm", "15bpm", "18bpm", "20bpm"]:plt.plot(test_pickle[experiment][ex]["forehead-wrist"]["forehead"]["t"],
test_pickle[experiment][ex]["forehead-wrist"]["forehead"]["ppg_g"])
     
pks = test_pickle[experiment][ex]["forehead-wrist"]["forehead"]["pks_g"]
if len(pks) != 0:
    plt.plot(pks[1], pks[2], color='red', linestyle='None', marker='o', markersize=1.5, alpha=1.0)

# %%
for ex in ["10bpm", "12bpm", "15bpm", "18bpm", "20bpm"]:plt.plot(test_pickle[experiment][ex]["forehead-wrist"]["wrist"]["t"],
test_pickle[experiment][ex]["forehead-wrist"]["wrist"]["ppg_g"])
     
pks = test_pickle[experiment][ex]["forehead-wrist"]["wrist"]["pks_g"]
if len(pks) != 0:
    plt.plot(pks[1], pks[2], color='red', linestyle='None', marker='o', markersize=1.5, alpha=1.0)

plt.xlim((0.0, 180.0))
plt.show()
